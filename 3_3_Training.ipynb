# %%
# The generic script for training ResNet-18 models for predicting DHS asset-wealth is as follows: 
# training_poverty.ipynb

# python train_dhs.py \
#     --label_name wealthpooled --batcher base \
#     --model_name resnet --num_layers 18 \
#     --lr_decay 0.96 --batch_size 64 \
#     --gpu 0 --num_threads 5 \
#     --cache train,train_eval,val \
#     --augment True --eval_every 1 --print_every 40 \
#     --ooc {ooc} --max_epochs {max_epochs} \
#     --out_dir {out_dir} \
#     --keep_frac {keep_frac} --seed {seed} \
#     --experiment_name {experiment_name} \
#     --dataset {dataset} \
#     --ls_bands {ls_bands} --nl_band {nl_band} \
#     --lr {lr} --fc_reg {reg} --conv_reg {reg} \
#     --imagenet_weights_path {imagenet_weights_path} \
#     --hs_weight_init {hs_weight_init}

# %% [markdown]
# ## TRAINING MS

# %%
# remember to mount if in drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### IncomeIDHM

# %% [markdown]
# ## MS

# %%
# OOC_A MS (2010)

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_A_ms_samescaled \
        --dataset IDHM_OOC_A \
        --ls_bands ms \
        --lr 0.0001 --fc_reg 0.01 --conv_reg 0.01 \
        --imagenet_weights_path /content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz
# Out:
# 2022-12-02 12:01:30.782811: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Current time: 1669982494.4380393
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 0.01,
#  'dataset': 'IDHM_OOC_A',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_A_ms_samescaled',
#  'fc_reg': 0.01,
#  'gpu': 0,
#  'hs_weight_init': 'samescaled',
#  'imagenet_weights_path': '/content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz',
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 0.0001,
#  'lr_decay': 0.96,
#  'ls_bands': 'ms',
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': None,
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
# OOC_B MS (2010)

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_B_ms_samescaled \
        --dataset IDHM_OOC_B \
        --ls_bands ms \
        --lr 0.0001 --fc_reg 0.01 --conv_reg 0.01 \
        --imagenet_weights_path /content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz
# Out:
# 2022-12-02 12:37:42.113934: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Current time: 1669984665.0425243
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 0.01,
#  'dataset': 'IDHM_OOC_B',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_B_ms_samescaled',
#  'fc_reg': 0.01,
#  'gpu': 0,
#  'hs_weight_init': 'samescaled',
#  'imagenet_weights_path': '/content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz',
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 0.0001,
#  'lr_decay': 0.96,
#  'ls_bands': 'ms',
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': None,
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
# OOC_C MS (2010)

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_C_ms_samescaled \
        --dataset IDHM_OOC_C \
        --ls_bands ms \
        --lr 0.0001 --fc_reg 0.01 --conv_reg 0.01 \
        --imagenet_weights_path /content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz
# Out:
# 2022-12-02 13:13:08.138786: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Current time: 1669986791.346646
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 0.01,
#  'dataset': 'IDHM_OOC_C',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_C_ms_samescaled',
#  'fc_reg': 0.01,
#  'gpu': 0,
#  'hs_weight_init': 'samescaled',
#  'imagenet_weights_path': '/content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz',
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 0.0001,
#  'lr_decay': 0.96,
#  'ls_bands': 'ms',
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': None,
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
# OOC_D MS (2010)

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_D_ms_samescaled \
        --dataset IDHM_OOC_D \
        --ls_bands ms \
        --lr 0.0001 --fc_reg 0.01 --conv_reg 0.01 \
        --imagenet_weights_path /content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz
# Out:
# 2022-12-02 13:48:13.725318: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Current time: 1669988896.6837025
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 0.01,
#  'dataset': 'IDHM_OOC_D',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_D_ms_samescaled',
#  'fc_reg': 0.01,
#  'gpu': 0,
#  'hs_weight_init': 'samescaled',
#  'imagenet_weights_path': '/content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz',
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 0.0001,
#  'lr_decay': 0.96,
#  'ls_bands': 'ms',
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': None,
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
# OOC_E MS (2010)

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init samescaled \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --ooc --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_E_ms_samescaled \
        --dataset IDHM_OOC_E \
        --ls_bands ms \
        --lr 0.0001 --fc_reg 0.01 --conv_reg 0.01 \
        --imagenet_weights_path /content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz
# Out:
# 2022-12-02 14:20:40.719215: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Current time: 1669990843.7006752
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 0.01,
#  'dataset': 'IDHM_OOC_E',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_E_ms_samescaled',
#  'fc_reg': 0.01,
#  'gpu': 0,
#  'hs_weight_init': 'samescaled',
#  'imagenet_weights_path': '/content/drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz',
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 0.0001,
#  'lr_decay': 0.96,
#  'ls_bands': 'ms',
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': None,
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %% [markdown]
# Extract features

# %%
# !python extract_features.py
# Out:
# 2022-12-03 14:36:00.049147: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ====== Current Config: ======
# - dataset: idhm
# - ls_bands: ms
# - nl_band: None
# - model_arch: resnet
# - number of models: 5
#
# Building model...
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:561: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# ...

# %% [markdown]
# ## NL

# %%
# OOC_A NL 2010
# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_A_nl_random \
        --ooc \
        --dataset IDHM_OOC_A \
        --nl_band split \
        --lr 0.00001 --fc_reg 1.0 --conv_reg 1.0
# Out:
# 2022-12-03 02:59:20.285640: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# entrei aqui no run_training_wrapper
# Current time: 1670036363.665085
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 1.0,
#  'dataset': 'IDHM_OOC_A',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_A_nl_random',
#  'fc_reg': 1.0,
#  'gpu': 0,
#  'hs_weight_init': 'random',
#  'imagenet_weights_path': None,
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 1e-05,
#  'lr_decay': 0.96,
#  'ls_bands': None,
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': 'split',
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
# OOC_B NL 2010
# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_B_nl_random \
        --ooc \
        --dataset IDHM_OOC_B \
        --nl_band split \
        --lr 0.00001 --fc_reg 1.0 --conv_reg 1.0
# Out:
# 2022-12-03 03:16:09.877035: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# entrei aqui no run_training_wrapper
# Current time: 1670037372.7173302
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 1.0,
#  'dataset': 'IDHM_OOC_B',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_B_nl_random',
#  'fc_reg': 1.0,
#  'gpu': 0,
#  'hs_weight_init': 'random',
#  'imagenet_weights_path': None,
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 1e-05,
#  'lr_decay': 0.96,
#  'ls_bands': None,
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': 'split',
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
# OOC_C NL 2010
# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 128 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_C_nl_random \
        --ooc \
        --dataset IDHM_OOC_C \
        --nl_band split \
        --lr 0.00001 --fc_reg 1.0 --conv_reg 1.0
# Out:
# 2022-12-03 13:11:19.816140: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# entrei aqui no run_training_wrapper
# Current time: 1670073082.6920483
# {'augment': True,
#  'batch_size': 128,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 1.0,
#  'dataset': 'IDHM_OOC_C',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_C_nl_random',
#  'fc_reg': 1.0,
#  'gpu': 0,
#  'hs_weight_init': 'random',
#  'imagenet_weights_path': None,
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 1e-05,
#  'lr_decay': 0.96,
#  'ls_bands': None,
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': 'split',
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
# OOC_D NL 2010
# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_D_nl_random \
        --ooc \
        --dataset IDHM_OOC_D \
        --nl_band split \
        --lr 0.00001 --fc_reg 1.0 --conv_reg 1.0
# Out:
# 2022-12-03 03:43:38.599977: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# entrei aqui no run_training_wrapper
# Current time: 1670039021.4701297
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 1.0,
#  'dataset': 'IDHM_OOC_D',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_D_nl_random',
#  'fc_reg': 1.0,
#  'gpu': 0,
#  'hs_weight_init': 'random',
#  'imagenet_weights_path': None,
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 1e-05,
#  'lr_decay': 0.96,
#  'ls_bands': None,
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': 'split',
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
# OOC_E NL 2010
# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init random \
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_E_nl_random \
        --ooc \
        --dataset IDHM_OOC_E \
        --nl_band split \
        --lr 0.00001 --fc_reg 1.0 --conv_reg 1.0
# Out:
# 2022-12-03 14:13:50.681980: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# entrei aqui no run_training_wrapper
# Current time: 1670076833.7038991
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 1.0,
#  'dataset': 'IDHM_OOC_E',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_E_nl_random',
#  'fc_reg': 1.0,
#  'gpu': 0,
#  'hs_weight_init': 'random',
#  'imagenet_weights_path': None,
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 1e-05,
#  'lr_decay': 0.96,
#  'ls_bands': None,
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': 'split',
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
# !python extract_features.py
# Out:
# 2022-12-03 14:50:01.825089: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ====== Current Config: ======
# - dataset: idhm
# - ls_bands: None
# - nl_band: split
# - model_arch: resnet
# - number of models: 5
#
# Building model...
# 2022-12-03 14:50:06.370589: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## RGB

# %%
#OOC_A RGB 2010

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_A_rgb_same \
        --dataset IDHM_OOC_A \
        --ooc \
        --ls_band rgb \
        --lr 0.01 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz
# Out:
# 2022-12-02 16:59:53.959664: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Current time: 1670000396.8590896
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 0.001,
#  'dataset': 'IDHM_OOC_A',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_A_rgb_same',
#  'fc_reg': 0.001,
#  'gpu': 0,
#  'hs_weight_init': 'same',
#  'imagenet_weights_path': 'drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz',
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 0.01,
#  'lr_decay': 0.96,
#  'ls_bands': 'rgb',
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': None,
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
#OOC_B RGB 2010

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_B_rgb_same \
        --dataset IDHM_OOC_B \
        --ooc \
        --ls_band rgb \
        --lr 0.01 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz
# Out:
# 2022-12-02 17:17:31.593981: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Current time: 1670001454.6004508
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 0.001,
#  'dataset': 'IDHM_OOC_B',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_B_rgb_same',
#  'fc_reg': 0.001,
#  'gpu': 0,
#  'hs_weight_init': 'same',
#  'imagenet_weights_path': 'drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz',
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 0.01,
#  'lr_decay': 0.96,
#  'ls_bands': 'rgb',
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': None,
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
#OOC_C RGB 2010

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_C_rgb_same \
        --dataset IDHM_OOC_C \
        --ooc \
        --ls_band rgb \
        --lr 0.01 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz
# Out:
# 2022-12-02 17:35:03.957807: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Current time: 1670002506.7805023
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 0.001,
#  'dataset': 'IDHM_OOC_C',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_C_rgb_same',
#  'fc_reg': 0.001,
#  'gpu': 0,
#  'hs_weight_init': 'same',
#  'imagenet_weights_path': 'drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz',
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 0.01,
#  'lr_decay': 0.96,
#  'ls_bands': 'rgb',
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': None,
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
#OOC_D RGB 2010

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_D_rgb_same \
        --dataset IDHM_OOC_D \
        --ooc \
        --ls_band rgb \
        --lr 0.01 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz
# Out:
# 2022-12-02 17:52:38.780745: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Current time: 1670003561.616567
# {'augment': True,
#  'batch_size': 64,
#  'cache': ['train', 'train_eval', 'val'],
#  'conv_reg': 0.001,
#  'dataset': 'IDHM_OOC_D',
#  'eval_every': 1,
#  'exclude_final_layer': False,
#  'experiment_name': 'IncomeIDHM_OOC_D_rgb_same',
#  'fc_reg': 0.001,
#  'gpu': 0,
#  'hs_weight_init': 'same',
#  'imagenet_weights_path': 'drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz',
#  'init_ckpt_dir': None,
#  'keep_frac': 1.0,
#  'label_name': 'IncomeIDHM',
#  'lr': 0.01,
#  'lr_decay': 0.96,
#  'ls_bands': 'rgb',
#  'max_epochs': 150,
#  'model_name': 'resnet',
#  'nl_band': None,
#  'num_layers': 18,
#  'num_threads': 5,
#  'ooc': True,
# ...

# %%
#OOC_E RGB 2010

# !python train_direct.py \
        --label_name IncomeIDHM \
        --hs_weight_init same\
        --model_name resnet --num_layers 18 \
        --lr_decay 0.96 --batch_size 64 \
        --gpu 0 --num_threads 5 \
        --cache train train_eval val \
        --augment --eval_every 1 --print_every 40 \
        --max_epochs 150 \
        --out_dir drive/MyDrive/USP/TCC/data/training2/idhm/income \
        --keep_frac 1.0 --seed 123 \
        --experiment_name IncomeIDHM_OOC_E_rgb_same \
        --dataset IDHM_OOC_E \
        --ooc \
        --ls_band rgb \
        --lr 0.01 --fc_reg 0.001 --conv_reg 0.001 \
        --imagenet_weights_path drive/MyDrive/ImageNet-ResNet18/ImageNet-ResNet18.npz

# %%
# !python extract_features.py
# Out:
# 2022-12-03 15:02:08.106190: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ====== Current Config: ======
# - dataset: idhm
# - ls_bands: rgb
# - nl_band: None
# - model_arch: resnet
# - number of models: 5
#
# Building model...
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:561: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# ...
